# %% [markdown]
# # Whimsy
#
# To determine the "best" neighborhood, we created this sub-metric, "Whimsy", which is based on how entertaining a neighborhood is through how many parks it  has. In conclusion, the more playgrounds a neighborhood has, the higher its "Whimsy" score which is out of 20. In the data set below, the neighborhoods are extremely specific and hard to effectively categorize and analyze, therefore, we chose to analyze the maintenance responsibility column instead as each maintenance group covers a broader area.

# %%
import pandas as pd

wh = pd.read_csv("playgrounds.csv")
wh.head(20)
# Out:
#     _id          id                            name  type  \
# 0     1   731501774            Able Long Playground   NaN
# 1     2  1461276747        Albert Graham Playground   NaN
# 2     3  1860709784               Alpine Playground   NaN
# 3     4  1770671485                Alton Playground   NaN
# 4     5    18942817                Ammon Playground   NaN
# 5     6   230731204            Arlington Playground   NaN
# 6     7   420573029            Armstrong Playground   NaN
# 7     8   113170092              Arsenal Playground   NaN
# 8     9  2089697067        August WIlson Playground   NaN
# 9    10  2124405123           Banksville Playground   NaN
# 10   11   202656658               Baxter Playground   NaN
# 11   12   966305264              Bon Air Playground   NaN
# 12   13  1687972299      Boundary Street Playground   NaN
# 13   14   966240511     Brighton Heights Playground   NaN
# 14   15  2126090864            Brookline Playground   NaN
# ...

# %% [markdown]
# the code below looks through the maintenance responsibility column and takes note of all unique variables in that column and the amount of times it appears in said column.

# %%
sorted_counts = wh['maintenance_responsibility'].value_counts().sort_values(ascending=False)
print(sorted_counts)
# Out:
# maintenance_responsibility
# Parks - Western      25
# Parks - Schenley     24
# Parks - Southern     21
# Parks - Northern     19
# Parks - Northeast    19
# Parks - Eastern      12
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("playgrounds.csv")

# Count each instance of each responsibility in the 'Maintenance Responsibility' column
neighborhood_counts = df['maintenance_responsibility'].value_counts()

# Bar graph
neighborhood_counts.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Maintenance Responsibility')
plt.ylabel('Count of Responsibilities')  # Corrected to a string label for the y-axis
plt.title('Count of Maintenance Responsibilities for Parks in Pittsburgh')
plt.xticks(rotation=45, ha='right')
plt.tight_layout() 
plt.show()

# %% [markdown]
# Conclusion: For "Whimsiness", we scored Oakland a 20/20 because although it came in second, Schenley mainly only covers Oakland and has an amount of parks almost equal to that of Western which covers about 3-4 neighborhoods.
